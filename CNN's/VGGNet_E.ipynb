# %% [markdown]
# # VGGNet_E or VGG19
#
# VGG_E is commonly known as VGG19 is considered to be a "very deep network" due to having 19 trainable layer.
#
# VGGNet uses small kernel sizes (uses 3 except in VGGNet_C's 7th, 10th and 13th convolution layers) and stride 1.
#
# More information can be found in [VERY DEEP CONVOLUTIONAL NETWORKS
# FOR LARGE-SCALE IMAGE RECOGNITION](https://arxiv.org/pdf/1409.1556.pdf) by Karen Simonyan& Andrew Zisserman.
#
# ### Architecture
# input -> conv3-64 -> conv3-64 -> maxpool -> conv3-128 -> conv3-128 -> maxpool -> conv3-256 -> conv3-256 -> conv3-256 -> conv3-256 -> maxpool -> conv3-512 -> conv3-512 -> conv3-512 -> conv3-512 -> maxpool -> conv3-512 -> conv3-512 -> conv3-512 -> conv3-512 -> maxpool -> flatten -> fc4096 -> fc4096 -> output
#
# ### Note :
# Because of the small image sizes, paddings are changed to "SAME".

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers import Input
from keras.layers import Activation
from keras.models import Model
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %%
from data import get_data_set

# %%
# Args
save_dir = "./results"
batch_size = 32
epochs = 350
lr=0.001
decay=0.0005
momentum=0.9
log_dir = "./tensorboard/VGGNet_E_9x9_13/"
# originals
# save_dir = "./results"
# batch_size = 50
# epochs = 50
# lr=0.01
# decay=0.0005
# momentum=0.9

# %%
X_train,Y_train = get_data_set("train",input_path = "../input/data_9x9_13band/",one_hot = True)
X_test,Y_test = get_data_set("test",input_path = "../input/data_9x9_13band/", one_hot = True)

X_train.shape
# Out:
# (404, 9, 9, 13)

# %%
tensorboard = TensorBoard(log_dir=log_dir,batch_size=batch_size)

# %%
inputs = Input(X_train.shape[1:])
inputs
# Out:
# <tf.Tensor 'input_1:0' shape=(?, 9, 9, 13) dtype=float32>

# %%
conv_1 = Convolution2D(64, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_1')(inputs)
conv_2 = Convolution2D(64, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_2')(conv_1)
conv_2 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(conv_2)

# %%
conv_3 = Convolution2D(128, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_3')(conv_2)
conv_4 = Convolution2D(128, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_4')(conv_3)
conv_4 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(conv_4)

# %%
conv_5 = Convolution2D(256, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_5')(conv_4)
conv_6 = Convolution2D(256, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_6')(conv_5)
conv_7 = Convolution2D(256, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_7')(conv_6)
conv_8 = Convolution2D(256, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_8')(conv_7)
conv_8 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(conv_8)

# %%
conv_9 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_9')(conv_8)
conv_10 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_10')(conv_9)
conv_11 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_11')(conv_10)
conv_12 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_12')(conv_11)
conv_12 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(conv_12)

# %%
conv_13 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_13')(conv_12)
conv_14 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_14')(conv_13)
conv_15 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_15')(conv_14)
conv_16 = Convolution2D(512, kernel_size =(3, 3), strides=(1, 1), padding='same', activation='relu',
                           name='conv_16')(conv_15)
conv_16 = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(conv_16)

# %%
dense_1 = Flatten(name='flatten')(conv_16)

# %%
dense_1 = Dense(4096, activation='relu', name='dense_1')(dense_1)
dense_2 = Dropout(0.5)(dense_1)
dense_2 = Dense(4096, activation='relu', name='dense_2')(dense_2)
dense_3 = Dropout(0.5)(dense_2)
dense_3 = Dense(Y_train.shape[1], name='dense_3')(dense_3)
prediction = Activation('softmax', name='softmax')(dense_3)
prediction
# Out:
# <tf.Tensor 'softmax/Softmax:0' shape=(?, 4) dtype=float32>

# %%
model = Model(outputs=prediction,inputs = inputs)

# %% [markdown]
# # Lets train

# %%
# optimizer
sgd = SGD(lr=lr, decay=decay, momentum=momentum)

# %%
model.compile(optimizer=sgd, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 9, 9, 13)          0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 9, 9, 64)          7552
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 5, 5, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 3, 3, 256)         295168
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 3, 3, 256)         590080
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 3, 3, 256)         590080
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv_9 (Conv2D)              (None, 2, 2, 512)         1180160
# _________________________________________________________________
# conv_10 (Conv2D)             (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv_11 (Conv2D)             (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv_12 (Conv2D)             (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv_13 (Conv2D)             (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv_14 (Conv2D)             (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv_15 (Conv2D)             (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv_16 (Conv2D)             (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              2101248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 16388
# _________________________________________________________________
# softmax (Activation)         (None, 4)                 0
# =================================================================
# Total params: 38,929,092
# Trainable params: 38,929,092
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x = X_train, y = Y_train, batch_size=batch_size, epochs=epochs,
              validation_data=[X_test,Y_test],shuffle = True,
              callbacks=[tensorboard])
# Out:
# Train on 404 samples, validate on 793 samples
# Epoch 1/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.3863 - acc: 0.2426 - val_loss: 1.3846 - val_acc: 0.4540
# Epoch 2/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.3861 - acc: 0.2475 - val_loss: 1.3825 - val_acc: 0.2232
# Epoch 3/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3856 - acc: 0.2673 - val_loss: 1.3811 - val_acc: 0.2232
# Epoch 4/350
# 404/404 [==============================] - 19s 46ms/step - loss: 1.3853 - acc: 0.2970 - val_loss: 1.3794 - val_acc: 0.2232
# Epoch 5/350
# 404/404 [==============================] - 18s 45ms/step - loss: 1.3851 - acc: 0.2673 - val_loss: 1.3769 - val_acc: 0.2232
# Epoch 6/350
# 404/404 [==============================] - 18s 46ms/step - loss: 1.3847 - acc: 0.2599 - val_loss: 1.3756 - val_acc: 0.2232
# Epoch 7/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3845 - acc: 0.2624 - val_loss: 1.3741 - val_acc: 0.2232
# Epoch 8/350
# 404/404 [==============================] - 19s 46ms/step - loss: 1.3841 - acc: 0.2698 - val_loss: 1.3729 - val_acc: 0.2232
# Epoch 9/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.3837 - acc: 0.2748 - val_loss: 1.3717 - val_acc: 0.2232
# Epoch 10/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3835 - acc: 0.2896 - val_loss: 1.3699 - val_acc: 0.3455
# Epoch 11/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.3831 - acc: 0.3045 - val_loss: 1.3690 - val_acc: 0.2232
# Epoch 12/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.3831 - acc: 0.2599 - val_loss: 1.3676 - val_acc: 0.2232
# Epoch 13/350
# 404/404 [==============================] - 18s 45ms/step - loss: 1.3825 - acc: 0.2649 - val_loss: 1.3676 - val_acc: 0.2232
# Epoch 14/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3820 - acc: 0.2698 - val_loss: 1.3668 - val_acc: 0.2232
# Epoch 15/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.3816 - acc: 0.2624 - val_loss: 1.3654 - val_acc: 0.2232
# Epoch 16/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3812 - acc: 0.2673 - val_loss: 1.3638 - val_acc: 0.2232
# Epoch 17/350
# 404/404 [==============================] - 20s 50ms/step - loss: 1.3807 - acc: 0.2723 - val_loss: 1.3638 - val_acc: 0.2232
# Epoch 18/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.3801 - acc: 0.2624 - val_loss: 1.3628 - val_acc: 0.2232
# Epoch 19/350
# 404/404 [==============================] - 21s 52ms/step - loss: 1.3795 - acc: 0.2698 - val_loss: 1.3611 - val_acc: 0.2232
# Epoch 20/350
# 404/404 [==============================] - 18s 46ms/step - loss: 1.3789 - acc: 0.2649 - val_loss: 1.3612 - val_acc: 0.2232
# Epoch 21/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3779 - acc: 0.2772 - val_loss: 1.3591 - val_acc: 0.2232
# Epoch 22/350
# 404/404 [==============================] - 19s 46ms/step - loss: 1.3773 - acc: 0.2649 - val_loss: 1.3582 - val_acc: 0.2232
# Epoch 23/350
# 404/404 [==============================] - 18s 44ms/step - loss: 1.3762 - acc: 0.2748 - val_loss: 1.3572 - val_acc: 0.2232
# Epoch 24/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.3754 - acc: 0.2772 - val_loss: 1.3560 - val_acc: 0.2232
# Epoch 25/350
# 404/404 [==============================] - 20s 50ms/step - loss: 1.3739 - acc: 0.3094 - val_loss: 1.3540 - val_acc: 0.2232
# Epoch 26/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.3728 - acc: 0.2871 - val_loss: 1.3531 - val_acc: 0.2232
# Epoch 27/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.3710 - acc: 0.3342 - val_loss: 1.3503 - val_acc: 0.2245
# Epoch 28/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.3704 - acc: 0.3094 - val_loss: 1.3494 - val_acc: 0.2245
# Epoch 29/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.3688 - acc: 0.3119 - val_loss: 1.3471 - val_acc: 0.2257
# Epoch 30/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.3669 - acc: 0.3490 - val_loss: 1.3444 - val_acc: 0.2787
# Epoch 31/350
# 404/404 [==============================] - 22s 55ms/step - loss: 1.3655 - acc: 0.3738 - val_loss: 1.3422 - val_acc: 0.3039
# Epoch 32/350
# 404/404 [==============================] - 21s 52ms/step - loss: 1.3629 - acc: 0.3663 - val_loss: 1.3382 - val_acc: 0.4061
# Epoch 33/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.3606 - acc: 0.3911 - val_loss: 1.3375 - val_acc: 0.4212
# Epoch 34/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3577 - acc: 0.4183 - val_loss: 1.3331 - val_acc: 0.4477
# Epoch 35/350
# 404/404 [==============================] - 18s 46ms/step - loss: 1.3553 - acc: 0.4183 - val_loss: 1.3279 - val_acc: 0.4603
# Epoch 36/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.3516 - acc: 0.4282 - val_loss: 1.3235 - val_acc: 0.4414
# Epoch 37/350
# 404/404 [==============================] - 22s 54ms/step - loss: 1.3476 - acc: 0.4208 - val_loss: 1.3183 - val_acc: 0.4426
# Epoch 38/350
# 404/404 [==============================] - 18s 44ms/step - loss: 1.3423 - acc: 0.4059 - val_loss: 1.3118 - val_acc: 0.4338
# Epoch 39/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.3371 - acc: 0.4010 - val_loss: 1.2991 - val_acc: 0.3834
# Epoch 40/350
# 404/404 [==============================] - 20s 50ms/step - loss: 1.3302 - acc: 0.3688 - val_loss: 1.2880 - val_acc: 0.3834
# Epoch 41/350
# 404/404 [==============================] - 20s 50ms/step - loss: 1.3202 - acc: 0.3366 - val_loss: 1.2726 - val_acc: 0.3871
# Epoch 42/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.3034 - acc: 0.3391 - val_loss: 1.2434 - val_acc: 0.3884
# Epoch 43/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.2826 - acc: 0.3589 - val_loss: 1.2085 - val_acc: 0.3884
# Epoch 44/350
# 404/404 [==============================] - 21s 52ms/step - loss: 1.2540 - acc: 0.3564 - val_loss: 1.1592 - val_acc: 0.3884
# Epoch 45/350
# 404/404 [==============================] - 19s 47ms/step - loss: 1.2071 - acc: 0.4208 - val_loss: 1.1026 - val_acc: 0.3884
# Epoch 46/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.1664 - acc: 0.4703 - val_loss: 1.0906 - val_acc: 0.4439
# Epoch 47/350
# 404/404 [==============================] - 20s 51ms/step - loss: 1.1468 - acc: 0.5173 - val_loss: 1.0365 - val_acc: 0.3897
# Epoch 48/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.1011 - acc: 0.5718 - val_loss: 1.0277 - val_acc: 0.3922
# Epoch 49/350
# 404/404 [==============================] - 21s 53ms/step - loss: 1.0936 - acc: 0.5594 - val_loss: 0.9733 - val_acc: 0.4010
# Epoch 50/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.0466 - acc: 0.5792 - val_loss: 0.9159 - val_acc: 0.4842
# Epoch 51/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.9856 - acc: 0.6337 - val_loss: 0.8551 - val_acc: 0.4956
# Epoch 52/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.9286 - acc: 0.6238 - val_loss: 1.0435 - val_acc: 0.4338
# Epoch 53/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.9707 - acc: 0.6139 - val_loss: 0.8066 - val_acc: 0.7049
# Epoch 54/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.9305 - acc: 0.6262 - val_loss: 2.1993 - val_acc: 0.1412
# Epoch 55/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.1827 - acc: 0.4851 - val_loss: 1.0339 - val_acc: 0.3960
# Epoch 56/350
# 404/404 [==============================] - 18s 45ms/step - loss: 1.0653 - acc: 0.5198 - val_loss: 0.9947 - val_acc: 0.6356
# Epoch 57/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.9776 - acc: 0.5693 - val_loss: 1.0158 - val_acc: 0.4439
# Epoch 58/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.7906 - acc: 0.6460 - val_loss: 0.9387 - val_acc: 0.4868
# Epoch 59/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.7405 - acc: 0.6510 - val_loss: 0.7903 - val_acc: 0.5195
# Epoch 60/350
# 404/404 [==============================] - 21s 51ms/step - loss: 1.0076 - acc: 0.5817 - val_loss: 2.0383 - val_acc: 0.2547
# Epoch 61/350
# 404/404 [==============================] - 20s 49ms/step - loss: 1.0769 - acc: 0.5198 - val_loss: 1.2034 - val_acc: 0.4187
# Epoch 62/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.9700 - acc: 0.5792 - val_loss: 1.0511 - val_acc: 0.4792
# Epoch 63/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.7865 - acc: 0.6733 - val_loss: 0.9573 - val_acc: 0.4779
# Epoch 64/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.6362 - acc: 0.6683 - val_loss: 0.8355 - val_acc: 0.5107
# Epoch 65/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.6230 - acc: 0.6559 - val_loss: 0.8095 - val_acc: 0.4918
# Epoch 66/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.5819 - acc: 0.6782 - val_loss: 0.7526 - val_acc: 0.5195
# Epoch 67/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.7195 - acc: 0.6807 - val_loss: 0.9062 - val_acc: 0.4842
# Epoch 68/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.5990 - acc: 0.7079 - val_loss: 0.7370 - val_acc: 0.7289
# Epoch 69/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.6320 - acc: 0.6510 - val_loss: 0.7645 - val_acc: 0.5322
# Epoch 70/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.5577 - acc: 0.7203 - val_loss: 0.7441 - val_acc: 0.5095
# Epoch 71/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.5876 - acc: 0.6757 - val_loss: 0.7340 - val_acc: 0.7566
# Epoch 72/350
# 404/404 [==============================] - 22s 55ms/step - loss: 0.5683 - acc: 0.6832 - val_loss: 0.7505 - val_acc: 0.5334
# Epoch 73/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.5298 - acc: 0.6856 - val_loss: 0.7048 - val_acc: 0.7314
# Epoch 74/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.5239 - acc: 0.7228 - val_loss: 0.7629 - val_acc: 0.7465
# Epoch 75/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.4950 - acc: 0.7698 - val_loss: 0.8131 - val_acc: 0.7579
# Epoch 76/350
# 404/404 [==============================] - 22s 55ms/step - loss: 0.5604 - acc: 0.7203 - val_loss: 0.8314 - val_acc: 0.4868
# Epoch 77/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.5470 - acc: 0.7104 - val_loss: 0.7048 - val_acc: 0.7768
# Epoch 78/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.5247 - acc: 0.7104 - val_loss: 0.8280 - val_acc: 0.5006
# Epoch 79/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.5118 - acc: 0.7129 - val_loss: 0.7713 - val_acc: 0.5498
# Epoch 80/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.5455 - acc: 0.7178 - val_loss: 0.6875 - val_acc: 0.7667
# Epoch 81/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.4791 - acc: 0.7450 - val_loss: 0.7284 - val_acc: 0.5410
# Epoch 82/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.4778 - acc: 0.7327 - val_loss: 0.6994 - val_acc: 0.7755
# Epoch 83/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.4311 - acc: 0.7995 - val_loss: 0.8670 - val_acc: 0.6936
# Epoch 84/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.3885 - acc: 0.8639 - val_loss: 0.6818 - val_acc: 0.8071
# Epoch 85/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.5049 - acc: 0.7946 - val_loss: 0.6518 - val_acc: 0.7617
# Epoch 86/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.6172 - acc: 0.7277 - val_loss: 0.7700 - val_acc: 0.5347
# Epoch 87/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.4868 - acc: 0.7723 - val_loss: 0.7146 - val_acc: 0.7276
# Epoch 88/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.4258 - acc: 0.8267 - val_loss: 1.3383 - val_acc: 0.5750
# Epoch 89/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.4977 - acc: 0.7624 - val_loss: 0.7965 - val_acc: 0.7264
# Epoch 90/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.3662 - acc: 0.8663 - val_loss: 0.6635 - val_acc: 0.7932
# Epoch 91/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.2696 - acc: 0.9257 - val_loss: 0.8161 - val_acc: 0.7730
# Epoch 92/350
# 404/404 [==============================] - 22s 53ms/step - loss: 0.3762 - acc: 0.8639 - val_loss: 0.5996 - val_acc: 0.7932
# Epoch 93/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.3215 - acc: 0.8837 - val_loss: 0.5978 - val_acc: 0.7831
# Epoch 94/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.3280 - acc: 0.8837 - val_loss: 0.7896 - val_acc: 0.7453
# Epoch 95/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.4432 - acc: 0.8441 - val_loss: 0.5302 - val_acc: 0.8096
# Epoch 96/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.3481 - acc: 0.8787 - val_loss: 0.6511 - val_acc: 0.7881
# Epoch 97/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.3669 - acc: 0.8688 - val_loss: 0.6730 - val_acc: 0.7465
# Epoch 98/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.2270 - acc: 0.9505 - val_loss: 0.7282 - val_acc: 0.7957
# Epoch 99/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.2243 - acc: 0.9158 - val_loss: 0.5759 - val_acc: 0.8398
# Epoch 100/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.3744 - acc: 0.8713 - val_loss: 0.5027 - val_acc: 0.8361
# Epoch 101/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.3552 - acc: 0.8960 - val_loss: 0.7529 - val_acc: 0.7402
# Epoch 102/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.4782 - acc: 0.8045 - val_loss: 0.5126 - val_acc: 0.8272
# Epoch 103/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.3924 - acc: 0.8787 - val_loss: 0.5873 - val_acc: 0.8285
# Epoch 104/350
# 404/404 [==============================] - 23s 56ms/step - loss: 0.2692 - acc: 0.9084 - val_loss: 0.9046 - val_acc: 0.7579
# Epoch 105/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.2458 - acc: 0.9257 - val_loss: 0.7193 - val_acc: 0.7894
# Epoch 106/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.2016 - acc: 0.9356 - val_loss: 0.6295 - val_acc: 0.7957
# Epoch 107/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.2757 - acc: 0.9084 - val_loss: 0.5722 - val_acc: 0.8172
# Epoch 108/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.3046 - acc: 0.9010 - val_loss: 0.5694 - val_acc: 0.8159
# Epoch 109/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.1674 - acc: 0.9505 - val_loss: 0.6030 - val_acc: 0.8335
# Epoch 110/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1394 - acc: 0.9604 - val_loss: 0.5369 - val_acc: 0.8449
# Epoch 111/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.1354 - acc: 0.9678 - val_loss: 0.5269 - val_acc: 0.8474
# Epoch 112/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.1118 - acc: 0.9703 - val_loss: 0.5414 - val_acc: 0.8449
# Epoch 113/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.0991 - acc: 0.9678 - val_loss: 0.5031 - val_acc: 0.8550
# Epoch 114/350
# 404/404 [==============================] - 22s 55ms/step - loss: 0.0910 - acc: 0.9777 - val_loss: 0.6850 - val_acc: 0.8272
# Epoch 115/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1143 - acc: 0.9653 - val_loss: 0.6225 - val_acc: 0.8386
# Epoch 116/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1124 - acc: 0.9604 - val_loss: 0.8122 - val_acc: 0.7932
# Epoch 117/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.1398 - acc: 0.9505 - val_loss: 0.6251 - val_acc: 0.8386
# Epoch 118/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.1147 - acc: 0.9579 - val_loss: 0.5240 - val_acc: 0.8499
# Epoch 119/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.0830 - acc: 0.9728 - val_loss: 0.5876 - val_acc: 0.8146
# Epoch 120/350
# 404/404 [==============================] - 21s 52ms/step - loss: 0.0898 - acc: 0.9653 - val_loss: 0.5471 - val_acc: 0.8436
# Epoch 121/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.0987 - acc: 0.9653 - val_loss: 0.5579 - val_acc: 0.8361
# Epoch 122/350
# 404/404 [==============================] - 19s 48ms/step - loss: 0.1078 - acc: 0.9653 - val_loss: 0.5067 - val_acc: 0.8411
# Epoch 123/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.0617 - acc: 0.9802 - val_loss: 0.5828 - val_acc: 0.8449
# Epoch 124/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.0468 - acc: 0.9777 - val_loss: 0.6616 - val_acc: 0.8398
# Epoch 125/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.0752 - acc: 0.9653 - val_loss: 0.8177 - val_acc: 0.8096
# Epoch 126/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.1049 - acc: 0.9678 - val_loss: 0.9806 - val_acc: 0.7377
# Epoch 127/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.1241 - acc: 0.9579 - val_loss: 0.6995 - val_acc: 0.8184
# Epoch 128/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1069 - acc: 0.9629 - val_loss: 0.6504 - val_acc: 0.8424
# Epoch 129/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.1251 - acc: 0.9505 - val_loss: 0.7270 - val_acc: 0.8020
# Epoch 130/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.0835 - acc: 0.9752 - val_loss: 0.5786 - val_acc: 0.8512
# Epoch 131/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.0888 - acc: 0.9728 - val_loss: 0.6024 - val_acc: 0.8537
# Epoch 132/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.1160 - acc: 0.9629 - val_loss: 0.7245 - val_acc: 0.8146
# Epoch 133/350
# 404/404 [==============================] - 21s 51ms/step - loss: 0.1284 - acc: 0.9629 - val_loss: 0.7890 - val_acc: 0.7932
# Epoch 134/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.0861 - acc: 0.9653 - val_loss: 0.9210 - val_acc: 0.7680
# Epoch 135/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.2150 - acc: 0.9332 - val_loss: 0.8551 - val_acc: 0.7654
# Epoch 136/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.1688 - acc: 0.9480 - val_loss: 0.4716 - val_acc: 0.8575
# Epoch 137/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.0702 - acc: 0.9728 - val_loss: 0.5851 - val_acc: 0.8474
# Epoch 138/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.0911 - acc: 0.9703 - val_loss: 1.0507 - val_acc: 0.7591
# Epoch 139/350
# 404/404 [==============================] - 18s 43ms/step - loss: 0.0926 - acc: 0.9678 - val_loss: 0.5417 - val_acc: 0.8588
# Epoch 140/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.0712 - acc: 0.9728 - val_loss: 0.6166 - val_acc: 0.8373
# Epoch 141/350
# 404/404 [==============================] - 22s 55ms/step - loss: 0.0763 - acc: 0.9777 - val_loss: 0.5411 - val_acc: 0.8361
# Epoch 142/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.0767 - acc: 0.9752 - val_loss: 0.7428 - val_acc: 0.8310
# Epoch 143/350
# 404/404 [==============================] - 21s 53ms/step - loss: 0.0506 - acc: 0.9827 - val_loss: 0.6144 - val_acc: 0.8550
# Epoch 144/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.0418 - acc: 0.9827 - val_loss: 0.6858 - val_acc: 0.8525
# Epoch 145/350
# 404/404 [==============================] - 18s 43ms/step - loss: 0.1446 - acc: 0.9480 - val_loss: 0.9485 - val_acc: 0.7907
# Epoch 146/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1338 - acc: 0.9604 - val_loss: 0.5531 - val_acc: 0.8487
# Epoch 147/350
# 404/404 [==============================] - 23s 56ms/step - loss: 0.0714 - acc: 0.9752 - val_loss: 0.5204 - val_acc: 0.8575
# Epoch 148/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.0540 - acc: 0.9901 - val_loss: 0.5704 - val_acc: 0.8625
# Epoch 149/350
# 404/404 [==============================] - 22s 53ms/step - loss: 0.0355 - acc: 0.9926 - val_loss: 0.5917 - val_acc: 0.8676
# Epoch 150/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.0333 - acc: 0.9901 - val_loss: 0.6955 - val_acc: 0.8386
# Epoch 151/350
# 404/404 [==============================] - 18s 44ms/step - loss: 0.0380 - acc: 0.9901 - val_loss: 0.7092 - val_acc: 0.8462
# Epoch 152/350
# 404/404 [==============================] - 17s 43ms/step - loss: 0.0396 - acc: 0.9901 - val_loss: 0.6393 - val_acc: 0.8651
# Epoch 153/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.9516 - acc: 0.8168 - val_loss: 1.5364 - val_acc: 0.5195
# Epoch 154/350
# 404/404 [==============================] - 21s 53ms/step - loss: 0.9310 - acc: 0.5965 - val_loss: 0.9599 - val_acc: 0.5574
# Epoch 155/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.7317 - acc: 0.7748 - val_loss: 0.7792 - val_acc: 0.5132
# Epoch 156/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.4729 - acc: 0.7772 - val_loss: 0.6221 - val_acc: 0.8474
# Epoch 157/350
# 404/404 [==============================] - 18s 43ms/step - loss: 0.3103 - acc: 0.9332 - val_loss: 0.6664 - val_acc: 0.8462
# Epoch 158/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.1656 - acc: 0.9604 - val_loss: 0.7187 - val_acc: 0.8449
# Epoch 159/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.1552 - acc: 0.9604 - val_loss: 0.5145 - val_acc: 0.8726
# Epoch 160/350
# 404/404 [==============================] - 20s 49ms/step - loss: 0.1018 - acc: 0.9752 - val_loss: 0.5816 - val_acc: 0.8600
# Epoch 161/350
# 404/404 [==============================] - 18s 45ms/step - loss: 0.0926 - acc: 0.9777 - val_loss: 0.6316 - val_acc: 0.8625
# Epoch 162/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.0815 - acc: 0.9851 - val_loss: 0.5766 - val_acc: 0.8638
# Epoch 163/350
# 404/404 [==============================] - 22s 54ms/step - loss: 0.1061 - acc: 0.9678 - val_loss: 1.1262 - val_acc: 0.7276
# Epoch 164/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.2429 - acc: 0.9257 - val_loss: 0.9679 - val_acc: 0.7566
# Epoch 165/350
# 404/404 [==============================] - 19s 46ms/step - loss: 0.2387 - acc: 0.9183 - val_loss: 0.5151 - val_acc: 0.8285
# Epoch 166/350
# 404/404 [==============================] - 20s 50ms/step - loss: 0.1607 - acc: 0.9455 - val_loss: 0.4631 - val_acc: 0.8689
# Epoch 167/350
# 404/404 [==============================] - 19s 47ms/step - loss: 0.0710 - acc: 0.9827 - val_loss: 0.5725 - val_acc: 0.8550
# Epoch 168/350
# 404/404 [==============================] - 20s 51ms/step - loss: 0.0594 - acc: 0.9777 - val_loss: 0.5206 - val_acc: 0.8613
# Epoch 169/350
# 288/404 [====================>.........] - ETA: 5s - loss: 0.0600 - acc: 0.9792
